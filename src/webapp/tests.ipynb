# %%
# %reload_ext autoreload
# %autoreload 2

import os, sys
from pprint import pprint
import django
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "config.settings")
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

from apps.events import models
from apps.events.models import Event, Related
# Event.objects.filter(id='DBC-100000').delete()
# Event.objects.create(id='DBC-100000')
e0 = Event.objects.filter(id='DBC-100000').first()
# Event.objects.filter(id='DBC-100000').exclude(pk=e0.pk).delete()
# e0.headline = 'New Headline'
# e0.description = 'Description'
# e0.metadata = {'one': 1}
# e0.save()
# e1 = Event.objects.filter(id='DBC-100001').first()
# e1.current = True
# e1.save(force_update=True)
# e1.save()
# print(e1.pk)

# pprint(dir(e0))
# pprint(e0.__dict__)
# pprint(e0.__dict__['_state'])
r2 = Related.objects.get(name='R2')
ex = r2.event
print(ex)
pprint(ex.related_set.first())

# for event in Event.objects.filter(id='DBC-100001'):
#     print(event, event.pk)
# Out:
# {'instance': <Related: Related object (3)>}
# related event manager
# ['__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slotnames__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_constructor_args',
#  '_db',
#  '_get_queryset_methods',
#  '_hints',
#  '_insert',
#  '_queryset_class',
#  '_set_creation_counter',
#  '_update',
#  'aaggregate',
#  'abulk_create',
#  'abulk_update',
#  'acontains',
#  'acount',
#  'acreate',
#  'aearliest',
#  'aexists',
#  'aexplain',
#  'afirst',
#  'aget',
#  'aget_or_create',
#  'aggregate',
#  'ain_bulk',
#  'aiterator',
# ...
